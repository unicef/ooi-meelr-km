# %% [markdown]
# This is a POC of Nvidia NIM with llamaindex

# %%
import getpass
import os

del os.environ['NVIDIA_API_KEY']  ## delete key and reset
#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
if os.environ.get("NVIDIA_API_KEY", "").startswith("nvapi-"):
    print("Valid NVIDIA_API_KEY already in environment. Delete to reset")
else:
    nvapi_key = getpass.getpass("NVAPI Key (starts with nvapi-): ")
    assert nvapi_key.startswith(
        "nvapi-"
    ), f"{nvapi_key[:5]}... is not a valid key"
    os.environ["NVIDIA_API_KEY"] = nvapi_key

# %%
from llama_index.core import Settings
from llama_index.llms.nvidia import NVIDIA
from llama_index.embeddings.nvidia import NVIDIAEmbedding
from llama_index.core.node_parser import SentenceSplitter
from llama_index.core import SimpleDirectoryReader
from llama_index.core import VectorStoreIndex
import nest_asyncio

nest_asyncio.apply()
# Settings.llm = NVIDIA(model="nvidia/nv-embedqa-mistral-7b-v2")
Settings.llm = NVIDIA(model="mistralai/mixtral-8x7b-instruct-v0.1")
Settings.embed_model = NVIDIAEmbedding(model="NV-Embed-QA", truncate="END")
TOY_DATA_PATH = "/proj/staff/jayant/rag/ooi-meelr-km/data"

# %%
Settings.text_splitter = SentenceSplitter(chunk_size=400)
documents = SimpleDirectoryReader(TOY_DATA_PATH).load_data()

index = VectorStoreIndex.from_documents(documents)

# %%
query_engine = index.as_query_engine(similarity_top_k=10)

response = query_engine.query(
    "how did unicef help in innovation?"
)
print(response)
# Out:
# ---------------------------------------------------------------------------
# APIStatusError                            Traceback (most recent call last)
# Cell In[25], line 3
#       1 query_engine = index.as_query_engine(similarity_top_k=10)
# ----> 3 response = query_engine.query(
#       4     "how did unicef help in innovation?"
#       5 )
#       6 print(response)
#
# File /proj/staff/jayant/CONDA_ENVS/coar_rag_env/lib/python3.12/site-packages/llama_index/core/instrumentation/dispatcher.py:311, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     308             _logger.debug(f"Failed to reset active_span_id: {e}")
#     310 try:
# --> 311     result = func(*args, **kwargs)
#     312     if isinstance(result, asyncio.Future):
#     313         # If the result is a Future, wrap it
#     314         new_future = asyncio.ensure_future(result)
#
# ...
